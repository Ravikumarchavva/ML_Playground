# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Survived"]==1) & (df["Pclass"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
from matplotlib import pyplot as plt

plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Display the plot
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
filterd_data=df[['Sex','Age','SibSp',
       'Parch','Embarked','Pclass']]

# %%
filterd_data
# Out:
#         Sex   Age  SibSp  Parch Embarked  Pclass
# 0      male  22.0      1      0        S       3
# 1    female  38.0      1      0        C       1
# 2    female  26.0      0      0        S       3
# 3    female  35.0      1      0        S       1
# 4      male  35.0      0      0        S       3
# ..      ...   ...    ...    ...      ...     ...
# 886    male  27.0      0      0        S       2
# 887  female  19.0      0      0        S       1
# 888  female   NaN      1      2        S       3
# 889    male  26.0      0      0        C       1
# 890    male  32.0      0      0        Q       3
#
# [891 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.drop("Cabin",axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Embarked'].fillna(df['Embarked'].mode,inplace=True)

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.replace({'Sex':{'male':0,'female':1},'Embarked':{'S':0,'C':1,'Q':2}},inplace=True)

# %%
x=df.drop(['PassengerId','Name','Ticket','Survived','Embarked'],axis=1)
y=df['Survived']

# %%
x["Embarked"]=filterd_data["Embarked"]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
x['Embarked']=label.fit_transform(x['Embarked'])

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500         2
# 1         1    1  38.000000      1      0  71.2833         0
# 2         3    1  26.000000      0      0   7.9250         2
# 3         1    1  35.000000      1      0  53.1000         2
# 4         3    0  35.000000      0      0   8.0500         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000         2
# 887       1    1  19.000000      0      0  30.0000         2
# 888       3    1  29.699118      1      2  23.4500         2
# 889       1    0  26.000000      0      0  30.0000         0
# 890       3    0  32.000000      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction)
# Out:
# 0.7877094972067039

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500         2
# 1         1    1  38.000000      1      0  71.2833         0
# 2         3    1  26.000000      0      0   7.9250         2
# 3         1    1  35.000000      1      0  53.1000         2
# 4         3    0  35.000000      0      0   8.0500         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000         2
# 887       1    1  19.000000      0      0  30.0000         2
# 888       3    1  29.699118      1      2  23.4500         2
# 889       1    0  26.000000      0      0  30.0000         0
# 890       3    0  32.000000      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear') 
clf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv_pred=clf.predict(x_test)

# %%
accuracy_score(y_test,sv_pred)
# Out:
# 0.7597765363128491

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree_pred=clf.predict(x_test)
accuracy_score(y_test,tree_pred)
# Out:
# 0.7485714285714286

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rtree = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rtree.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rtree_pred=clf.predict(x_test)
accuracy_score(y_test,rtree_pred)
# Out:
# 0.7485714285714286

# %%
x['Survived']=y

# %%
import numpy as np
x['z_score'] = np.abs((x['Fare'] - x['Fare'].mean()) / x['Fare'].std())

# %%
outlier_data=x[x['z_score']<=3]

# %%
outlier_data=outlier_data.drop('z_score',axis=1)

# %%
outlier_data
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  Survived
# 0         3    0  22.000000      1      0   7.2500         2         0
# 1         1    1  38.000000      1      0  71.2833         0         1
# 2         3    1  26.000000      0      0   7.9250         2         1
# 3         1    1  35.000000      1      0  53.1000         2         1
# 4         3    0  35.000000      0      0   8.0500         2         0
# ..      ...  ...        ...    ...    ...      ...       ...       ...
# 886       2    0  27.000000      0      0  13.0000         2         0
# 887       1    1  19.000000      0      0  30.0000         2         1
# 888       3    1  29.699118      1      2  23.4500         2         0
# 889       1    0  26.000000      0      0  30.0000         0         1
# 890       3    0  32.000000      0      0   7.7500         1         0
#
# [871 rows x 8 columns]

# %%
x=outlier_data.drop('Survived',axis=1)
y=outlier_data['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=2)

# %%
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
out_pred=model.predict(x_test)

# %%
accuracy_score(y_test,out_pred)
# Out:
# 0.7941176470588235

# %%
outlier_data['Survived']=y

# %%
outlier_data['z_score'] = np.abs((outlier_data['Fare'] - outlier_data['Fare'].mean()) / outlier_data['Fare'].std())

# %%
outlier_data=outlier_data[outlier_data['z_score']<=3]

# %%
outlier_data
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  Survived  \
# 0         3    0  22.000000      1      0   7.2500         2         0
# 1         1    1  38.000000      1      0  71.2833         0         1
# 2         3    1  26.000000      0      0   7.9250         2         1
# 3         1    1  35.000000      1      0  53.1000         2         1
# 4         3    0  35.000000      0      0   8.0500         2         0
# ..      ...  ...        ...    ...    ...      ...       ...       ...
# 886       2    0  27.000000      0      0  13.0000         2         0
# 887       1    1  19.000000      0      0  30.0000         2         1
# 888       3    1  29.699118      1      2  23.4500         2         0
# 889       1    0  26.000000      0      0  30.0000         0         1
# 890       3    0  32.000000      0      0   7.7500         1         0
#
#       z_score
# 0    0.656879
# 1    1.524747
# 2    0.633881
# 3    0.905239
# 4    0.629623
# ..        ...
# ...
