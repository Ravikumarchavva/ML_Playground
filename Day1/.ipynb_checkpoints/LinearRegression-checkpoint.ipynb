# %%
import numpy as np
import seaborn as sns
import pandas as pd
import polars as pl
from functions.eda import *
from functions.cat_eda import *
from functions.num_eda import *

# %%
data=pl.read_csv("CarPrice_Assignment.csv").drop(["car_ID","symboling","CarName"])
data.head()
# Out:
# shape: (5, 23)
# ┌──────────┬────────────┬────────────┬─────────────┬───┬─────────┬─────────┬────────────┬─────────┐
# │ fueltype ┆ aspiration ┆ doornumber ┆ carbody     ┆ … ┆ peakrpm ┆ citympg ┆ highwaympg ┆ price   │
# │ ---      ┆ ---        ┆ ---        ┆ ---         ┆   ┆ ---     ┆ ---     ┆ ---        ┆ ---     │
# │ str      ┆ str        ┆ str        ┆ str         ┆   ┆ i64     ┆ i64     ┆ i64        ┆ f64     │
# ╞══════════╪════════════╪════════════╪═════════════╪═══╪═════════╪═════════╪════════════╪═════════╡
# │ gas      ┆ std        ┆ two        ┆ convertible ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 13495.0 │
# │ gas      ┆ std        ┆ two        ┆ convertible ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 16500.0 │
# │ gas      ┆ std        ┆ two        ┆ hatchback   ┆ … ┆ 5000    ┆ 19      ┆ 26         ┆ 16500.0 │
# │ gas      ┆ std        ┆ four       ┆ sedan       ┆ … ┆ 5500    ┆ 24      ┆ 30         ┆ 13950.0 │
# │ gas      ┆ std        ┆ four       ┆ sedan       ┆ … ┆ 5500    ┆ 18      ┆ 22         ┆ 17450.0 │
# └──────────┴────────────┴────────────┴─────────────┴───┴─────────┴─────────┴────────────┴─────────┘

# %% [markdown]
# Check for Linearity between independent variables and dependent variable

# %%
sns.pairplot(data.to_pandas(),y_vars=["price"])

# %% [markdown]
# Missing Values

# %%
data.null_count().sum()
# Out:
# shape: (1, 23)
# ┌──────────┬────────────┬────────────┬─────────┬───┬─────────┬─────────┬────────────┬───────┐
# │ fueltype ┆ aspiration ┆ doornumber ┆ carbody ┆ … ┆ peakrpm ┆ citympg ┆ highwaympg ┆ price │
# │ ---      ┆ ---        ┆ ---        ┆ ---     ┆   ┆ ---     ┆ ---     ┆ ---        ┆ ---   │
# │ u32      ┆ u32        ┆ u32        ┆ u32     ┆   ┆ u32     ┆ u32     ┆ u32        ┆ u32   │
# ╞══════════╪════════════╪════════════╪═════════╪═══╪═════════╪═════════╪════════════╪═══════╡
# │ 0        ┆ 0          ┆ 0          ┆ 0       ┆ … ┆ 0       ┆ 0       ┆ 0          ┆ 0     │
# └──────────┴────────────┴────────────┴─────────┴───┴─────────┴─────────┴────────────┴───────┘

# %% [markdown]
# No missing

# %%
cat_cols=[col for col in data.columns if data[col].dtype== pl.String]
num_cols=[col for col in data.columns if data[col].dtype!= pl.String]

# %% [markdown]
# Categorical EDA

# %%
categorical_violin_plot(data.to_pandas(),cat_cols,"price")

# %%
# data=data.with_columns(data["carbody"].str.replace_many(["convertible","hardtop","hatchback","sedan","wagon"],["2","2","0","1","0"] ).cast(pl.Int64))
data=data.with_columns(data["drivewheel"].str.replace_many(["rwd","fwd","4wd"],["1","0","0"]).cast(pl.Int64))
data=data.with_columns(data["enginelocation"].str.replace_many(["front","rear"],["0","1"]).cast(pl.Int64))
data=data.with_columns(data["cylindernumber"].str.replace_many(["two","three","four","five","six","eight","twelve"],["2","3","4","5","6","8","12"]).cast(pl.Int64))
data=data.with_columns(data["fuelsystem"].is_in(["mpfi","idi"]).cast(pl.Int64))
data=data.drop(["carbody","enginetype","fueltype","aspiration","doornumber"])

# %%
cat_cols=[col for  col in cat_cols if col not in ["carbody","enginetype","fueltype","aspiration","doornumber"]]

# %%
data
# Out:
# shape: (205, 18)
# ┌────────────┬──────────────┬───────────┬───────────┬───┬─────────┬─────────┬────────────┬─────────┐
# │ drivewheel ┆ enginelocati ┆ wheelbase ┆ carlength ┆ … ┆ peakrpm ┆ citympg ┆ highwaympg ┆ price   │
# │ ---        ┆ on           ┆ ---       ┆ ---       ┆   ┆ ---     ┆ ---     ┆ ---        ┆ ---     │
# │ i64        ┆ ---          ┆ f64       ┆ f64       ┆   ┆ i64     ┆ i64     ┆ i64        ┆ f64     │
# │            ┆ i64          ┆           ┆           ┆   ┆         ┆         ┆            ┆         │
# ╞════════════╪══════════════╪═══════════╪═══════════╪═══╪═════════╪═════════╪════════════╪═════════╡
# │ 1          ┆ 0            ┆ 88.6      ┆ 168.8     ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 13495.0 │
# │ 1          ┆ 0            ┆ 88.6      ┆ 168.8     ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 16500.0 │
# │ 1          ┆ 0            ┆ 94.5      ┆ 171.2     ┆ … ┆ 5000    ┆ 19      ┆ 26         ┆ 16500.0 │
# │ 0          ┆ 0            ┆ 99.8      ┆ 176.6     ┆ … ┆ 5500    ┆ 24      ┆ 30         ┆ 13950.0 │
# │ 0          ┆ 0            ┆ 99.4      ┆ 176.6     ┆ … ┆ 5500    ┆ 18      ┆ 22         ┆ 17450.0 │
# │ …          ┆ …            ┆ …         ┆ …         ┆ … ┆ …       ┆ …       ┆ …          ┆ …       │
# │ 1          ┆ 0            ┆ 109.1     ┆ 188.8     ┆ … ┆ 5400    ┆ 23      ┆ 28         ┆ 16845.0 │
# │ 1          ┆ 0            ┆ 109.1     ┆ 188.8     ┆ … ┆ 5300    ┆ 19      ┆ 25         ┆ 19045.0 │
# │ 1          ┆ 0            ┆ 109.1     ┆ 188.8     ┆ … ┆ 5500    ┆ 18      ┆ 23         ┆ 21485.0 │
# │ 1          ┆ 0            ┆ 109.1     ┆ 188.8     ┆ … ┆ 4800    ┆ 26      ┆ 27         ┆ 22470.0 │
# │ 1          ┆ 0            ┆ 109.1     ┆ 188.8     ┆ … ┆ 5400    ┆ 19      ┆ 25         ┆ 22625.0 │
# └────────────┴──────────────┴───────────┴───────────┴───┴─────────┴─────────┴────────────┴─────────┘

# %%
categorical_violin_plot(data.to_pandas(),cat_cols,"price")

# %% [markdown]
# Numerical EDA

# %% [markdown]
# Univariate Analysis

# %%
# sns.pairplot(data[num_cols].to_pandas(),y_vars=num_cols)

# %% [markdown]
# Feature engineering

# %%
data=data.with_columns(pl.Series(data["horsepower"]/data["highwaympg"]).alias("power_to_milage_ratio"))

# %%
data=data.with_columns(pl.Series(data["carlength"]*data["carwidth"]).alias("carsize"))

# %%
data=data.with_columns(pl.Series(data["horsepower"]/data["peakrpm"]).alias("efficiency"))
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34392\1844616732.py in ?()
# ----> 1 data=data.with_columns(pl.Series(data["horsepower"]/data["peakrpm"]).alias("efficiency"))
#
# c:\Users\chavv\anaconda\envs\eda\lib\site-packages\polars\dataframe\frame.py in ?(self, item)
#    1129
#    1130         # select single column
#    1131         # df["foo"]
#    1132         if isinstance(item, str):
# -> 1133             return self.get_column(item)
#    1134
#    1135         # df[idx]
#    1136         if isinstance(item, int):
#
# c:\Users\chavv\anaconda\envs\eda\lib\site-packages\polars\dataframe\frame.py in ?(self, name)
#    6617                 2
#    6618                 3
#    6619         ]
#    6620         """
# -> 6621         return wrap_s(self._df.get_column(name))
#
# ColumnNotFoundError: peakrpm

# %%
plt.figure(figsize=(18,6))
sns.heatmap(data[["carsize","power_to_milage_ratio","efficiency"]+num_cols+cat_cols].to_pandas().corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot: >

# %%
num_cols=[col for  col in num_cols if col not in ["carheight",'wheelbase',"boreratio","compressionratio","peakrpm","stroke"]]

# %%
data=data.drop(["carheight","wheelbase","boreratio","compressionratio","peakrpm","stroke"])

# %% [markdown]
# We can drop wheel_base,population,households

# %%
data.to_pandas().hist(bins=20,figsize=(20,15))
plt.show()

# %%
corr=data.corr()[-4].transpose(include_header=True,column_names=["corr"])
corr.with_columns(np.abs(corr["corr"])).sort(by="corr",descending=True)
# Out:
# shape: (15, 2)
# ┌───────────────────────┬──────────┐
# │ column                ┆ corr     │
# │ ---                   ┆ ---      │
# │ str                   ┆ f64      │
# ╞═══════════════════════╪══════════╡
# │ price                 ┆ 1.0      │
# │ enginesize            ┆ 0.874145 │
# │ power_to_milage_ratio ┆ 0.857034 │
# │ curbweight            ┆ 0.835305 │
# │ horsepower            ┆ 0.808139 │
# │ …                     ┆ …        │
# │ citympg               ┆ 0.685751 │
# │ carlength             ┆ 0.68292  │
# │ drivewheel            ┆ 0.638957 │
# │ fuelsystem            ┆ 0.581681 │
# │ enginelocation        ┆ 0.324973 │
# └───────────────────────┴──────────┘

# %%
data1=data

# %%
X=data1.drop("price").to_pandas()
y=data1[["price"]].to_pandas()

# %%
from sklearn.preprocessing import StandardScaler
ssx=StandardScaler()
X=ssx.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca=PCA()
pca.fit(X)
# Out:
# PCA()

# %%
pca.
# Out:
# array([6.66149672e-01, 1.02703996e-01, 6.20333420e-02, 5.57395978e-02,
#        3.80439134e-02, 3.11409681e-02, 1.42173676e-02, 1.08277776e-02,
#        7.09653573e-03, 5.84018508e-03, 3.64146847e-03, 1.91810861e-03,
#        6.30841345e-04, 1.62260538e-05])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
pred=lr.predict(X_test)

r2_score(Y_test,pred)
# Out:
# 0.8464387005472085

# %%
score=[]
for i in range(0,100):
    X_train,X_test,Y_train,Y_test = train_test_split(data.drop("price").to_pandas(),data["price"].to_pandas(),test_size=0.2)
    lr=LinearRegression()
    lr.fit(X_train,Y_train)
    pred=lr.predict(X_test)
    # print(r2_score(Y_test,pred))
    score.append(r2_score(Y_test,pred))
print("Average R2 :",np.average(score))
# Out:
# Average R2 : 0.847670102302898

# %%
#comparision to tree based model
from catboost import CatBoostRegressor
score=[]
for i in range(1,30):
    X_train,X_test,Y_train,Y_test = train_test_split(data.drop("price").to_pandas(),data["price"].to_pandas(),test_size=0.2)
    catboost_classifier = CatBoostRegressor(
        colsample_bylevel=0.9,
        learning_rate=0.05,
        max_depth=5,
        n_estimators=300,
        reg_lambda=0.1,
        subsample=0.9,verbose=False
    )
    catboost_classifier.fit(X_train, Y_train)
    pred=catboost_classifier.predict(X_test)
    # print(r2_score(Y_test,pred))
    score.append(r2_score(Y_test,pred))
print("Average",np.average(score))
# Out:
# Average 0.9118367595934361
