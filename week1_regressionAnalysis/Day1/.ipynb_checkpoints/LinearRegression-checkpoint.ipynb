# %%
import numpy as np
import seaborn as sns
import pandas as pd
import polars as pl
from functions.eda import *
from functions.cat_eda import *
from functions.num_eda import *

# %%
data=pl.read_csv("CarPrice_Assignment.csv").drop(["car_ID","symboling","CarName"])
data.head()
# Out:
# shape: (5, 23)
# ┌──────────┬────────────┬────────────┬─────────────┬───┬─────────┬─────────┬────────────┬─────────┐
# │ fueltype ┆ aspiration ┆ doornumber ┆ carbody     ┆ … ┆ peakrpm ┆ citympg ┆ highwaympg ┆ price   │
# │ ---      ┆ ---        ┆ ---        ┆ ---         ┆   ┆ ---     ┆ ---     ┆ ---        ┆ ---     │
# │ str      ┆ str        ┆ str        ┆ str         ┆   ┆ i64     ┆ i64     ┆ i64        ┆ f64     │
# ╞══════════╪════════════╪════════════╪═════════════╪═══╪═════════╪═════════╪════════════╪═════════╡
# │ gas      ┆ std        ┆ two        ┆ convertible ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 13495.0 │
# │ gas      ┆ std        ┆ two        ┆ convertible ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 16500.0 │
# │ gas      ┆ std        ┆ two        ┆ hatchback   ┆ … ┆ 5000    ┆ 19      ┆ 26         ┆ 16500.0 │
# │ gas      ┆ std        ┆ four       ┆ sedan       ┆ … ┆ 5500    ┆ 24      ┆ 30         ┆ 13950.0 │
# ...

# %%
data.shape
# Out:
# (205, 23)

# %%
q1=data["price"].quantile(0.25)
q3=data["price"].quantile(0.75)
iqr=q3-q1
q1=q1-1*iqr
q3=q3+1.5*iqr
q1,q3
# Out:
# (-927.0, 29575.5)

# %%
iqrdata=data.filter(data["price"].is_in(np.arange(q1,q3)))
iqrdata
# Out:
# shape: (187, 23)
# ┌──────────┬────────────┬────────────┬─────────────┬───┬─────────┬─────────┬────────────┬─────────┐
# │ fueltype ┆ aspiration ┆ doornumber ┆ carbody     ┆ … ┆ peakrpm ┆ citympg ┆ highwaympg ┆ price   │
# │ ---      ┆ ---        ┆ ---        ┆ ---         ┆   ┆ ---     ┆ ---     ┆ ---        ┆ ---     │
# │ str      ┆ str        ┆ str        ┆ str         ┆   ┆ i64     ┆ i64     ┆ i64        ┆ f64     │
# ╞══════════╪════════════╪════════════╪═════════════╪═══╪═════════╪═════════╪════════════╪═════════╡
# │ gas      ┆ std        ┆ two        ┆ convertible ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 13495.0 │
# │ gas      ┆ std        ┆ two        ┆ convertible ┆ … ┆ 5000    ┆ 21      ┆ 27         ┆ 16500.0 │
# │ gas      ┆ std        ┆ two        ┆ hatchback   ┆ … ┆ 5000    ┆ 19      ┆ 26         ┆ 16500.0 │
# │ gas      ┆ std        ┆ four       ┆ sedan       ┆ … ┆ 5500    ┆ 24      ┆ 30         ┆ 13950.0 │
# ...

# %%
data=(data.filter(data["price"]<28000))

# %% [markdown]
# Check for Linearity between independent variables and dependent variable

# %%
sns.pairplot(iqrdata.to_pandas(),y_vars=["price"])

# %% [markdown]
# Missing Values

# %%
data.null_count().sum()
# Out:
# shape: (1, 23)
# ┌──────────┬────────────┬────────────┬─────────┬───┬─────────┬─────────┬────────────┬───────┐
# │ fueltype ┆ aspiration ┆ doornumber ┆ carbody ┆ … ┆ peakrpm ┆ citympg ┆ highwaympg ┆ price │
# │ ---      ┆ ---        ┆ ---        ┆ ---     ┆   ┆ ---     ┆ ---     ┆ ---        ┆ ---   │
# │ u32      ┆ u32        ┆ u32        ┆ u32     ┆   ┆ u32     ┆ u32     ┆ u32        ┆ u32   │
# ╞══════════╪════════════╪════════════╪═════════╪═══╪═════════╪═════════╪════════════╪═══════╡
# │ 0        ┆ 0          ┆ 0          ┆ 0       ┆ … ┆ 0       ┆ 0       ┆ 0          ┆ 0     │
# └──────────┴────────────┴────────────┴─────────┴───┴─────────┴─────────┴────────────┴───────┘

# %% [markdown]
# No missing

# %%
cat_cols=[col for col in data.columns if data[col].dtype== pl.String]
num_cols=[col for col in data.columns if data[col].dtype!= pl.String]

# %% [markdown]
# Categorical EDA

# %%
categorical_violin_plot(data.to_pandas(),cat_cols,"price")

# %%
# data=data.with_columns(data["drivewheel"].str.replace_many(["rwd","fwd","4wd"],["1","0","0"]).cast(pl.Int64))
# data=data.with_columns(data["enginelocation"].str.replace_many(["front","rear"],["0","1"]).cast(pl.Int64))
data=data.with_columns(data["cylindernumber"].str.replace_many(["two","three","four","five","six","eight","twelve"],["2","3","4","5","6","8","12"]).cast(pl.Int64))
data=data.with_columns(data["fuelsystem"].is_in(["mpfi","idi"]).cast(pl.Int64))
data=data.drop(["carbody","enginetype","fueltype","aspiration","enginelocation","doornumber","drivewheel"])

# %%
cat_cols=[col for  col in cat_cols if col not in ["carbody","enginetype","fueltype","aspiration","enginelocation","doornumber","drivewheel"]]

# %%
categorical_violin_plot(data.to_pandas(),cat_cols,"price")

# %% [markdown]
# Numerical EDA

# %% [markdown]
# Univariate analysis

# %%
data.to_pandas().hist(bins=6,figsize=(20,15))
plt.show()

# %%
plt.scatter(data["horsepower"].filter(data["horsepower"]<180),data.filter((data["horsepower"]<180))["price"])

# %%
plt.scatter(data["enginesize"],data["price"])

# %% [markdown]
# Bivariate Analysis

# %%
# sns.pairplot(data[num_cols].to_pandas(),y_vars=num_cols)

# %% [markdown]
# Feature engineering

# %%
data=data.with_columns(pl.Series(data["carlength"]*data["carwidth"]).alias("carsize"))

# %%
# data=data.with_columns(data["horsepower"].pow(0.05))

# %%
num_cols=num_cols+["carsize"]+cat_cols

# %%
plt.figure(figsize=(18,6))
sns.heatmap(data.to_pandas().corr(),annot=True,cmap="coolwarm",robust=True)
# Out:
# <AxesSubplot: >

# %%
num_cols=[col for  col in num_cols if col not in ["carheight",'wheelbase',"boreratio","compressionratio","peakrpm","stroke"]]

# %%
data=data.drop(["carheight","wheelbase","boreratio","compressionratio","peakrpm","stroke"])

# %% [markdown]
# We can drop wheel_base,population,households

# %%
from statsmodels.api import OLS
from sklearn.model_selection import train_test_split
X = data.drop(['price']).to_pandas()
y = data['price'].to_pandas()
X = X.drop(["highwaympg"],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X.drop([
                                                            # "carwidth"
                                                            "carlength"
                                                            ,"carsize"
                                                            # ,"curbweight"
                                                            ,"enginesize"
                                                            ,"fuelsystem"
                                                            ,"cylindernumber"
                                                            ,"horsepower"
                                                            # ,"citympg"
                        
                                                           ],axis=1), y, test_size=0.2)
ols=OLS(y_train,X_train).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              1157.
# Date:                Sat, 18 May 2024   Prob (F-statistic):                   5.24e-102
# Time:                        10:26:45   Log-Likelihood:                         -1386.4
# No. Observations:                 150   AIC:                                      2779.
# Df Residuals:                     147   BIC:                                      2788.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import r2_score
y_pred = ols.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.6511924811298289

# %%
X_test.shape,y_test.shape,y_pred.shape
# Out:
# ((38, 3), (38,), (38,))

# %%
# plt.scatter(X_test, y_test, color='blue', label='Actual')
# plt.scatter(X_test, y_pred, color='red', label='Predicted')

# Plotting the regression line
# plt.scatter(y_test, y_pred, color='green', marker='o', s=100, label='Predicted')
sns.regplot(x=y_test,y=y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
corr=data.corr()[-2].transpose(include_header=True,column_names=["corr"])
corr.with_columns(np.abs(corr["corr"])).sort(by="corr",descending=True)
# Out:
# shape: (11, 2)
# ┌────────────────┬──────────┐
# │ column         ┆ corr     │
# │ ---            ┆ ---      │
# │ str            ┆ f64      │
# ╞════════════════╪══════════╡
# │ price          ┆ 1.0      │
# │ curbweight     ┆ 0.843003 │
# │ carwidth       ┆ 0.77457  │
# │ carsize        ┆ 0.772718 │
# │ horsepower     ┆ 0.746    │
# │ …              ┆ …        │
# │ enginesize     ┆ 0.730507 │
# │ highwaympg     ┆ 0.696985 │
# │ citympg        ┆ 0.691979 │
# │ fuelsystem     ┆ 0.67258  │
# │ cylindernumber ┆ 0.451576 │
# └────────────────┴──────────┘

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

cat_cols=[col for col in data.columns if data[col].dtype== pl.String]
num_cols=[col for col in data.drop("price").columns if data[col].dtype!= pl.String]
preprocessor = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])


X = data.drop(['price']).to_pandas()
y = data['price'].to_pandas()

pipe = Pipeline([
    ('preprocessor', preprocessor),
    # ('model', LinearRegression())
])

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                  ('scaler', StandardScaler())]))])

# %%
X=pipe.fit_transform(X)

# %%
from statsmodels.api import OLS
from sklearn.model_selection import train_test_split
X = data.drop(['price']).to_pandas()
y = data['price'].to_pandas()
X_train, X_test, y_train, y_test = train_test_split(X.drop(["fuelsystem","cylindernumber","curbweight","enginesize","highwaympg","citympg","carwidth","carlength"],axis=1), y, test_size=0.2)
ols=OLS(y_train,X_train).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.937
# Model:                            OLS   Adj. R-squared (uncentered):              0.936
# Method:                 Least Squares   F-statistic:                              1102.
# Date:                Sat, 18 May 2024   Prob (F-statistic):                    1.33e-89
# Time:                        10:30:33   Log-Likelihood:                         -1416.4
# No. Observations:                 150   AIC:                                      2837.
# Df Residuals:                     148   BIC:                                      2843.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
y_pred = ols.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.5193974640195455

# %%
residuals=y_test - y_pred
sns.displot(residuals,kind='kde')

# %%
plt.scatter(y_test,y_pred)

# %%
y_pred=ols.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5193974640195455

# %%
r2s=[]
adjusted_r2s = []
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X.drop(["fuelsystem","cylindernumber","curbweight","enginesize","highwaympg","citympg","carwidth","carlength"],axis=1), y, test_size=0.2)
    lr=LinearRegression().fit(X_train,y_train)
    y_pred = lr.predict(X_test)
    r2=r2_score(y_test, y_pred)
    r2s.append(r2)
    adjusted_r2 = (1-(1-r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
    adjusted_r2s.append(adjusted_r2)
print("R2 :",np.average(r2s))
print("Adjusted R2",np.average(adjusted_r2s))
# Out:
# R2 : 0.710183605723592
# Adjusted R2 0.6936226689077973

# %%
models=[]
for i in range(0,100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,random_state=i)
    X_valid, X_test, y_valid, y_test = train_test_split(X, y, test_size=0.5,random_state=i)
    pipe.fit(X_train, y_train)
    models.append(pipe)
scores=[]
for i in models:
    y_pred = i.predict(X_valid)
    scores.append(r2_score(y_valid, y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 9
#       7 scores=[]
#       8 for i in models:
# ----> 9     y_pred = i.predict(X_valid)
#      10     scores.append(r2_score(y_valid, y_pred))
#
# File ~\anaconda\envs\eda\lib\site-packages\sklearn\utils\_available_if.py:32, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      26 attr_err = AttributeError(
#      27     f"This {repr(owner.__name__)} has no attribute {repr(self.attribute_name)}"
#      28 )
#      29 if obj is not None:
#      30     # delegate only on instances, not the classes.
#      31     # this is to allow access to the docstrings.
# ---> 32     if not self.check(obj):
#      33         raise attr_err
#      34     out = MethodType(self.fn, obj)
#
# File ~\anaconda\envs\eda\lib\site-packages\sklearn\pipeline.py:46, in _final_estimator_has.<locals>.check(self)
# ...

# %%
np.argmax(scores),np.average(scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 np.argmax(scores),np.average(scores)
#
# File <__array_function__ internals>:200, in argmax(*args, **kwargs)
#
# File ~\anaconda\envs\eda\lib\site-packages\numpy\core\fromnumeric.py:1242, in argmax(a, axis, out, keepdims)
#    1155 """
#    1156 Returns the indices of the maximum values along an axis.
#    1157
#    (...)
#    1239 (2, 1, 4)
#    1240 """
#    1241 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1242 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~\anaconda\envs\eda\lib\site-packages\numpy\core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# ...

# %%
y_pred = pipe.predict(X_test)
r2_score(y_test, y_pred)

# %% [markdown]
# Reducing Multicollinearity

# %%
from sklearn.decomposition import PCA
pca=PCA()
pca.fit(data.drop(['price']).to_dummies(columns=cat_cols))
# Out:
# PCA()

# %%
explained_variance_ratio = pca.explained_variance_ratio_

# Calculate cumulative explained variance ratio
cumulative_explained_variance = np.cumsum(explained_variance_ratio)
     
# Plot explained variance ratio vs. number of components
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(1, len(explained_variance_ratio) + 1), cumulative_explained_variance, where='mid', label='Cumulative explained variance')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Number of Components')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
pipe=Pipeline(steps=[
    ("pca",PCA(n_components=3)),
    ("model",LinearRegression())
])

# %%
pipe.fit(data.drop(['price']).to_dummies(columns=cat_cols),y)
# Out:
# Pipeline(steps=[('pca', PCA(n_components=3)), ('model', LinearRegression())])

# %%
score=[]
for i in range(0,100):
    X_train,X_test,Y_train,Y_test = train_test_split(data.drop(['price']).to_dummies(columns=cat_cols),y,test_size=0.2)
    pipe.fit(X_train,Y_train)
    pred=pipe.predict(X_test)
    score.append(r2_score(Y_test,pred))
print("Average R2 :",np.average(score))
# Out:
# Average R2 : 0.7364053228035907

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# Example pipeline (replace with your actual pipeline)
pipe = Pipeline([('model', LinearRegression())])

# Placeholder for scores
scores = []

for i in range(100):
    # Train-test split
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2, random_state=i)
    
    # Fit the model
    pipe.fit(X_train, Y_train)
    
    # Predict on the test set
    pred = pipe.predict(X_test)
    
    # Calculate R2 score
    r2 = r2_score(Y_test, pred)
    scores.append(r2)
    
# Average R2 score over 100 runs
print("Average R2:", np.mean(scores))

# Residual analysis
# Fit the model on the entire dataset for residual analysis
pipe.fit(X, y)
y_pred = pipe.predict(X)
residuals = y - y_pred

# Plot residuals vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

# Q-Q plot of residuals
# plt.figure(figsize=(8, 6))
# stats.probplot(residuals.to_numpy(), dist="norm", plot=plt)
# plt.title('Q-Q Plot of Residuals')
# plt.xlabel('Theoretical Quantiles')
# plt.ylabel('Sample Quantiles')
# plt.show()
# Out:
# Average R2: 0.7469177572868168

# %% [markdown]
# Homoscedasticity violated -> variance of residuals changing across the predicted values

# %%
#comparision to tree based model
from catboost import CatBoostRegressor
score=[]
for i in range(1,30):
    X_train,X_test,Y_train,Y_test = train_test_split(data.drop("price").to_pandas(),data["price"].to_pandas(),test_size=0.2)
    catboost_classifier = CatBoostRegressor(
        colsample_bylevel=0.9,
        learning_rate=0.05,
        max_depth=5,
        n_estimators=300,
        reg_lambda=0.1,
        subsample=0.9,verbose=False
    )
    catboost_classifier.fit(X_train, Y_train)
    pred=catboost_classifier.predict(X_test)
    score.append(r2_score(Y_test,pred))
print("Average",np.average(score))
