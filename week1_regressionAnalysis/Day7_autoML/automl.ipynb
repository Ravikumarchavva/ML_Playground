# %%
import pandas as pd
data = pd.read_csv("CarPrice_assignment.csv").drop("car_ID",axis=1)
data.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
from pycaret.regression import *
st=setup(data=data,target="price",remove_multicollinearity=True,train_size=0.7
         ,polynomial_features=True,remove_outliers=True)
# Out:
# <style type="text/css">
# #T_39ea1_row9_col1, #T_39ea1_row15_col1, #T_39ea1_row17_col1, #T_39ea1_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_39ea1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39ea1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_39ea1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39ea1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39ea1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_39ea1_row0_col1" class="data row0 col1" >7135</td>
#     </tr>
#     <tr>
#       <th id="T_39ea1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39ea1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_39ea1_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
# ...

# %%
bst=compare_models(include=["lr",'lasso','ridge','huber'])
# Out:
# <style type="text/css">
# #T_5af53 th {
#   text-align: left;
# }
# #T_5af53_row0_col0, #T_5af53_row1_col0, #T_5af53_row1_col1, #T_5af53_row1_col2, #T_5af53_row1_col3, #T_5af53_row1_col4, #T_5af53_row1_col5, #T_5af53_row1_col6, #T_5af53_row2_col0, #T_5af53_row2_col1, #T_5af53_row2_col2, #T_5af53_row2_col3, #T_5af53_row2_col4, #T_5af53_row2_col5, #T_5af53_row2_col6, #T_5af53_row3_col0, #T_5af53_row3_col1, #T_5af53_row3_col2, #T_5af53_row3_col3, #T_5af53_row3_col4, #T_5af53_row3_col5, #T_5af53_row3_col6 {
#   text-align: left;
# }
# #T_5af53_row0_col1, #T_5af53_row0_col2, #T_5af53_row0_col3, #T_5af53_row0_col4, #T_5af53_row0_col5, #T_5af53_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5af53_row0_col7, #T_5af53_row1_col7, #T_5af53_row3_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5af53_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5af53">
#   <thead>
# ...

# %%
evaluate_model(bst)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
create_model(bst)
# Out:
# <style type="text/css">
# #T_279ab_row10_col0, #T_279ab_row10_col1, #T_279ab_row10_col2, #T_279ab_row10_col3, #T_279ab_row10_col4, #T_279ab_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_279ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_279ab_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_279ab_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_279ab_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_279ab_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_279ab_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_279ab_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tm=tune_model(bst)
# Out:
# <style type="text/css">
# #T_eb6e1_row10_col0, #T_eb6e1_row10_col1, #T_eb6e1_row10_col2, #T_eb6e1_row10_col3, #T_eb6e1_row10_col4, #T_eb6e1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eb6e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb6e1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_eb6e1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_eb6e1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_eb6e1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_eb6e1_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_eb6e1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
data=pd.read_csv("erroranalysed.csv").drop("index",axis=1)
data
# Out:
#      curbweight  cylindernumber   carvolume   enginepower  averagempg    price
# 0          2548               0  528019.904  4.613226e+06       23.70  13495.0
# 1          2548               0  528019.904  4.613226e+06       23.70  16500.0
# 2          2823               1  587592.640  4.455542e+06       22.15  16500.0
# 3          2337               0  634816.956  3.841257e+06       26.70  13950.0
# 4          2824               1  636734.832  4.917072e+06       19.80  17450.0
# ..          ...             ...         ...           ...         ...      ...
# 178        2952               0  721961.760  5.919961e+06       25.25  16845.0
# 179        3049               0  720913.920  6.226185e+06       21.70  19045.0
# 180        3012               1  721961.760  7.245706e+06       20.25  21485.0
# 181        3217               1  721961.760  4.242935e+06       26.45  22470.0
# 182        3062               0  721961.760  5.919961e+06       21.70  22625.0
#
# [183 rows x 6 columns]

# %%
st1=setup(data=data,target="price",remove_multicollinearity=True,train_size=0.7
         ,remove_outliers=True)
# Out:
# <style type="text/css">
# #T_dc353_row8_col1, #T_dc353_row12_col1, #T_dc353_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dc353">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc353_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dc353_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc353_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc353_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dc353_row0_col1" class="data row0 col1" >7626</td>
#     </tr>
#     <tr>
#       <th id="T_dc353_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc353_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dc353_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
# ...

# %%
bst1=compare_models(include=["lr",'lasso','ridge','huber'])
# Out:
# <style type="text/css">
# #T_dae2a th {
#   text-align: left;
# }
# #T_dae2a_row0_col0, #T_dae2a_row1_col0, #T_dae2a_row1_col1, #T_dae2a_row1_col2, #T_dae2a_row1_col3, #T_dae2a_row1_col4, #T_dae2a_row1_col5, #T_dae2a_row2_col0, #T_dae2a_row2_col1, #T_dae2a_row2_col2, #T_dae2a_row2_col3, #T_dae2a_row2_col4, #T_dae2a_row2_col5, #T_dae2a_row2_col6, #T_dae2a_row3_col0, #T_dae2a_row3_col1, #T_dae2a_row3_col2, #T_dae2a_row3_col3, #T_dae2a_row3_col4, #T_dae2a_row3_col5, #T_dae2a_row3_col6 {
#   text-align: left;
# }
# #T_dae2a_row0_col1, #T_dae2a_row0_col2, #T_dae2a_row0_col3, #T_dae2a_row0_col4, #T_dae2a_row0_col5, #T_dae2a_row0_col6, #T_dae2a_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dae2a_row0_col7, #T_dae2a_row2_col7, #T_dae2a_row3_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dae2a_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dae2a">
#   <thead>
# ...

# %%
evaluate_model(bst1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tm1=tune_model(bst1)
# Out:
# <style type="text/css">
# #T_bb588_row10_col0, #T_bb588_row10_col1, #T_bb588_row10_col2, #T_bb588_row10_col3, #T_bb588_row10_col4, #T_bb588_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bb588">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb588_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bb588_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bb588_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bb588_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bb588_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bb588_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
